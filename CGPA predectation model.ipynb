# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
data=pd.read_csv("package.csv")

# %%
data
# Out:
#     CGPA  Salary
# 0    5.5      30
# 1    4.4      25
# 2    7.7      40
# 3    5.5      34
# 4    8.8      50
# 5    8.7      54
# 6    7.7      43
# 7    9.5      60
# 8    7.8      45
# 9    9.2      64
# 10   9.3      68
# 11   9.5      66
# 12   9.4      70

# %%
plt.figure(figsize=(4,4))
sns.scatterplot(x="CGPA",y="Salary",data=data)

plt.show()

# %%
data.isnull().sum()
# Out:
# CGPA      0
# Salary    0
# dtype: int64

# %%
x=data[["CGPA"]]
y=data[["Salary"]]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.predict([[5.6]])
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[31.22731418]])

# %%
lr.score(x_test,y_test)*100
# Out:
# 94.55872305557087

# %%
plt.figure(figsize=(4,4))
sns.scatterplot(x="CGPA",y="Salary",data=data)
plt.plot(data["CGPA"],lr.predict(x),color="red")
plt.show()

# %%
pwd
# Out:
# '/Users/princechaudhary/Downloads'
